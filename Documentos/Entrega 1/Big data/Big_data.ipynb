# %%
# 1) COLETAR DADOS INICIAIS
import pandas as pd
from IPython.display import display

# ler os 4 CSVs (ajuste o caminho se estiver em outra pasta)
order    = pd.read_csv('/content/Order_semicolon.csv', sep=';')
customer = pd.read_csv('/content/Customer_semicolon.csv', sep=';')
cqueue   = pd.read_csv('/content/CampaignQueue_semicolon.csv', sep=';')
campaign = pd.read_csv('/content/Campaign_semicolon.csv', sep=';')

datasets = {
    'Order': order,
    'Customer': customer,
    'CampaignQueue': cqueue,
    'Campaign': campaign
}

for name, df in datasets.items():
    print(f'\n=== {name} ===')
    print('shape:', df.shape)
    display(df.head(3))
    print(df.dtypes)
# Out:
# === Order ===
# shape: (2000, 23)
#    id   companyId containerId         createdAt  customer displayId engineId  \
# 0   1  I0VP1DZXGU    AKVXT2FH  08/01/2025 15:47       525    O8CC98   E3R037
# 1   2  04MEUULZ6W    KKMY5TG5  03/11/2024 22:30       694    HJ99VA   EJVOBV
# 2   3  W2ZZS7CCZW    I87JLGTV  09/09/2024 05:49       491    XJJDH2   UDX1ZF
#
#     engineName engineType                                     extraInfo  ...  \
# 0  DirectOrder        POS  Adipisci maiores nam eius vero nesciunt sed.  ...
# 1  DirectOrder        APP                                           NaN  ...
# 2       KDSPro        POS                                           NaN  ...
#
#    orderTiming  orderType  salesChannel scheduledAt      status  \
# 0    IMMEDIATE   DELIVERY       ANOTAAI         NaN  DISPATCHED
# 1    IMMEDIATE   DELIVERY      WHATSAPP         NaN   CONCLUDED
# 2    IMMEDIATE     INDOOR       EPADOCA         NaN   CONCLUDED
#
#   preparationTime takeOutTimeInSeconds totalAmount         updatedAt  version
# 0              45                 2131       90.91  09/01/2025 03:32   v3.7.8
# 1              33                  374       99.69  04/11/2024 03:05   v2.3.0
# 2              22                  247       45.97  09/09/2024 09:32   v1.9.5
#
# [3 rows x 23 columns]
# id                        int64
# companyId                object
# containerId              object
# createdAt                object
# customer                  int64
# displayId                object
# engineId                 object
# engineName               object
# engineType               object
# extraInfo                object
# integrated                 bool
# integrationId             int64
# isTest                     bool
# orderTiming              object
# orderType                object
# salesChannel             object
# scheduledAt              object
# status                   object
# preparationTime           int64
# takeOutTimeInSeconds      int64
# totalAmount             float64
# updatedAt                object
# version                  object
# dtype: object
#
# === Customer ===
# shape: (1000, 16)
#    id             name               taxId gender dateOfBirth  status  \
# 0   1  Fernanda Duarte      207.463.819-13      O  05/10/1972       1
# 1   2    Matheus Jesus  46.792.503/0001-48      M  19/03/1962       2
# 2   3     João da Mota      594.173.682-73      F  20/10/1991       1
#
#   externalCode  isEnriched        enrichedAt         enrichedBy  \
# 0          NaN        True  04/08/2024 02:29  franciscocarvalho
# 1          NaN       False               NaN                NaN
# 2     UZZPQK51        True  31/10/2023 02:50           calebe40
#
#           createdAt           createdBy         updatedAt           updatedBy  \
# 0  08/06/2024 02:29           pferreira  04/08/2024 02:29            wazevedo
# 1  29/12/2023 11:04             livia49  09/03/2024 11:04       ana-beatriz44
# 2  16/10/2023 02:50  lopesmaria-vitoria  31/10/2023 02:50  luiz-fernandopires
#
#          phone                       email
# 0  5,52193E+12         luigi67@hotmail.com
# 1  5,55192E+12         otavio28@bol.com.br
# 2  5,56191E+12  eduardasantos@yahoo.com.br
# id               int64
# name            object
# taxId           object
# gender          object
# dateOfBirth     object
# status           int64
# externalCode    object
# isEnriched        bool
# enrichedAt      object
# enrichedBy      object
# createdAt       object
# createdBy       object
# updatedAt       object
# updatedBy       object
# phone           object
# email           object
# dtype: object
#
# === CampaignQueue ===
# shape: (5000, 16)
#    id  jobId  campaignId     storeId storeInstanceId  customerId  \
# 0   1      1        1553  HJY9QRBZU0        AXHOTYUA         540
# 1   2      2        1890  8NQNTXHLZ7        QG7JQPEB         702
# 2   3      3         429  LQWCGSH3L1        EKF1PQGA          53
#
#              phoneNumber        scheduledAt            sendAt  status  \
# 0   5.521.962.375.590,00   23/01/2025 20:26  23/01/2025 22:23       5
# 1   5.551.963.199.134,00   25/04/2025 01:48  25/04/2025 02:52       4
# 2   5.584.949.992.702,00   04/11/2024 02:21               NaN       1
#
#                                              message  \
# 0  Adipisci placeat libero consectetur temporibus...
# 1  Reiciendis quaerat labore exercitationem exped...
# 2  Voluptas praesentium ut consequatur ab eius nu...
#
#                                             response         createdAt  \
# 0                                                NaN  23/01/2025 09:33
# 1  Sit illo ullam fugit quisquam quas delectus id...  25/04/2025 01:04
# 2                                                NaN  03/11/2024 05:44
#
#         createdBy         updatedAt  updatedBy
# 0          rsilva  24/01/2025 12:41  mirella55
# 1  lopesana-julia  25/04/2025 11:14     zviana
# 2     ana-livia25  03/11/2024 14:18   oda-cruz
# id                  int64
# jobId               int64
# campaignId          int64
# storeId            object
# storeInstanceId    object
# customerId          int64
#  phoneNumber       object
# scheduledAt        object
# sendAt             object
# status              int64
# message            object
# response           object
# createdAt          object
# createdBy          object
# updatedAt          object
# updatedBy          object
# dtype: object
#
# === Campaign ===
# shape: (2000, 14)
#    id  segmentId  templateId     storeId                      name  \
# 0   1          1           1  IWKESVR022       Campanha Saepe WGN5
# 1   2          2           2  GZSR8RUW2X  Campanha Voluptatem H6QI
# 2   3          3           3  F4JD1KSIBS      Campanha Itaque MQPN
#
#                                          description    badge  type  status  \
# 0  Excepturi earum quas quos tempora suscipit bea...  winback     2       4
# 1           Officia a facilis saepe iste illo nobis.  loyalty     2       4
# 2  Blanditiis ipsam qui odit quas minus rerum pra...      NaN     2       3
#
#    isDefault            createdAt            createdBy            updatedAt  \
# 0      False  2024-03-09 11:20:33            uda-costa  2024-08-23 11:20:33
# 1      False  2024-07-31 07:01:33            roliveira  2025-03-25 07:01:33
# 2       True  2024-06-06 05:15:59  maria-luizaoliveira  2025-03-25 05:15:59
#
#          updatedBy
# 0  luiz-henrique58
# 1         lcardoso
# 2          fmoraes
# id              int64
# segmentId       int64
# templateId      int64
# storeId        object
# name           object
# description    object
# badge          object
# type            int64
# status          int64
# isDefault        bool
# createdAt      object
# createdBy      object
# updatedAt      object
# updatedBy      object
# dtype: object

# %%
# 2) EXPLORAR OS DADOS
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display

for name, df in datasets.items():
    print(f'\n=== {name} ===')

    num_cols = df.select_dtypes(include=np.number).columns.tolist()
    cat_cols = df.select_dtypes(exclude=np.number).columns.tolist()

    # estatísticas
    if num_cols:
        print('\nEstatísticas numéricas:')
        display(df[num_cols].describe().T)

    if cat_cols:
        print('\nEstatísticas categóricas:')
        display(df[cat_cols].describe().T)

    # histogramas (até 5 numéricas)
    for c in num_cols[:5]:
        plt.figure()
        df[c].dropna().hist(bins=30)
        plt.title(f'{name} - {c}')
        plt.xlabel(c); plt.ylabel('freq')
        plt.tight_layout(); plt.show()

    # barras top-10 (até 3 categóricas)
    for c in cat_cols[:3]:
        vc = df[c].astype(str).value_counts().head(10)
        plt.figure()
        vc.plot(kind='bar')
        plt.title(f'{name} - {c} (top 10)')
        plt.xlabel(c); plt.ylabel('contagem')
        plt.tight_layout(); plt.show()

    # correlação se houver >=2 numéricas
    if len(num_cols) >= 2:
        corr = df[num_cols].corr(numeric_only=True)
        plt.figure()
        plt.imshow(corr, interpolation='nearest')
        plt.title(f'Correlação - {name}')
        plt.colorbar()
        plt.xticks(range(len(corr.columns)), corr.columns, rotation=90, fontsize=8)
        plt.yticks(range(len(corr.index)), corr.index, fontsize=8)
        plt.tight_layout(); plt.show()
# Out:
# === Order ===
#
# Estatísticas numéricas:
#                        count         mean          std      min      25%  \
# id                    2000.0  1000.500000   577.494589     1.00   500.75
# customer              2000.0   489.767500   287.741989     1.00   237.00
# integrationId         2000.0  5416.938000  2614.883850  1007.00  3147.75
# preparationTime       2000.0    47.327500    24.746948     5.00    26.00
# takeOutTimeInSeconds  2000.0  1842.534500  1012.435850    60.00   953.75
# totalAmount           2000.0    59.773255    35.455128    11.03    33.26
#
#                           50%        75%      max
# id                    1000.50  1500.2500  2000.00
# customer               490.50   729.0000  1000.00
# integrationId         5331.50  7700.2500  9993.00
# preparationTime         48.00    69.0000    90.00
# takeOutTimeInSeconds  1852.00  2710.5000  3598.00
# totalAmount             51.27    76.5375   239.04
# Estatísticas categóricas:
#              count unique                          top  freq
# companyId     2000   2000                   CRVSBAMFEF     1
# containerId   2000   2000                     O1RS3LFP     1
# createdAt     2000   1998             08/07/2025 15:41     2
# displayId     2000   2000                       7YKOBC     1
# engineId      2000   2000                       7TNPAR     1
# engineName    2000      4                  DirectOrder   538
# engineType    2000      3                          POS   691
# extraInfo      819    819  Nostrum neque perspiciatis.     1
# integrated    2000      2                         True  1197
# isTest        2000      2                        False  1911
# orderTiming   2000      2                    SCHEDULED  1032
# orderType     2000      3                     DELIVERY   688
# salesChannel  2000      7                      EPADOCA   296
# scheduledAt   1032   1031             30/03/2025 14:36     2
# status        2000      6                      PENDING   363
# updatedAt     2000   1998             04/06/2025 09:03     2
# version       2000    299                       v1.8.3    15
# === Customer ===
#
# Estatísticas numéricas:
#          count     mean         std  min     25%    50%     75%     max
# id      1000.0  500.500  288.819436  1.0  250.75  500.5  750.25  1000.0
# status  1000.0    1.508    0.500186  1.0    1.00    2.0    2.00     2.0
# Estatísticas categóricas:
#              count unique                      top freq
# name          1000    974  Gustavo Henrique Novaes    2
# taxId         1000   1000           150.748.293-05    1
# gender         741      3                        O  263
# dateOfBirth   1000    980               02/01/1981    2
# externalCode   374    374                 LPW71V4K    1
# isEnriched    1000      2                     True  504
# enrichedAt     504    504         28/02/2024 13:41    1
# enrichedBy     504    495                   nina33    2
# createdAt     1000    999         10/05/2024 10:50    2
# createdBy     1000    975                 ppeixoto    3
# updatedAt     1000   1000         28/02/2024 13:41    1
# updatedBy     1000    981                 bcardoso    2
# phone         1000     99              5,52193E+12   23
# email         1000    992       qbarbosa@gmail.com    2
# === CampaignQueue ===
#
# Estatísticas numéricas:
#              count       mean          std  min      25%     50%      75%  \
# id          5000.0  2500.5000  1443.520003  1.0  1250.75  2500.5  3750.25
# jobId       5000.0  2500.5000  1443.520003  1.0  1250.75  2500.5  3750.25
# campaignId  5000.0   997.2916   578.065819  1.0   504.50   994.0  1502.00
# customerId  5000.0   495.9774   288.729623  1.0   245.00   492.0   742.00
# status      5000.0     3.4780     1.719101  1.0     2.00     3.0     5.00
#
#                max
# id          5000.0
# jobId       5000.0
# campaignId  2000.0
# customerId  1000.0
# status         6.0
# Estatísticas categóricas:
#                 count unique  \
# storeId          5000   5000
# storeInstanceId  5000   5000
#  phoneNumber     5000    995
# scheduledAt      5000   4976
# sendAt           3288   3276
# message          5000   5000
# response         1588   1588
# createdAt        5000   4973
# createdBy        5000   4493
# updatedAt        5000   4976
# updatedBy        5000   4511
#
#                                                                top freq
# storeId                                                 RFYGO2XY5C    1
# storeInstanceId                                           WMGR04M7    1
#  phoneNumber                                 5.561.951.874.041,00    15
# scheduledAt                                       07/08/2025 13:31    2
# sendAt                                            16/06/2025 10:06    2
# message          Non veniam non porro doloremque nihil porro fu...    1
# response                        At delectus temporibus aspernatur.    1
# createdAt                                         07/01/2025 00:38    2
# createdBy                                                   osilva    5
# updatedAt                                         31/12/2024 06:56    2
# updatedBy                                                  ffarias    5
# === Campaign ===
#
# Estatísticas numéricas:
#              count       mean         std  min     25%     50%      75%  \
# id          2000.0  1000.5000  577.494589  1.0  500.75  1000.5  1500.25
# segmentId   2000.0   533.8875  482.953493  1.0    5.00   459.5   959.25
# templateId  2000.0  1000.5000  577.494589  1.0  500.75  1000.5  1500.25
# type        2000.0     1.4720    0.499340  1.0    1.00     1.0     2.00
# status      2000.0     2.5130    1.128480  1.0    1.75     3.0     4.00
#
#                max
# id          2000.0
# segmentId   1459.0
# templateId  2000.0
# type           2.0
# status         4.0
# Estatísticas categóricas:
#             count unique                                                top  \
# storeId      2000   2000                                         E45QZ9VX4X
# name         2000   2000                                  Campanha Vel SQ60
# description  1595   1595  Quis expedita aliquam a rerum ea dolores perfe...
# badge        1681      5                                        consumption
# isDefault    2000      2                                              False
# createdAt    2000   2000                                2024-01-21 18:30:55
# createdBy    2000   1908                                             uramos
# updatedAt    2000   2000                                2024-10-05 18:30:55
# updatedBy    2000   1909                                            zmendes
#
#              freq
# storeId         1
# name            1
# description     1
# badge         353
# isDefault    1696
# createdAt       1
# createdBy       3
# updatedAt       1
# updatedBy       3
# /tmp/ipython-input-3168210657.py:36: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout(); plt.show()
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
# 3) VERIFICAR A QUALIDADE DOS DADOS
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display

for name, df in datasets.items():
    print(f'\n=== {name} ===')

    # missing por coluna
    miss = (df.isna().mean()*100).sort_values(ascending=False)
    display(miss.to_frame('%_missing').head(20))
    plt.figure()
    miss.plot(kind='bar')
    plt.title(f'% missing por coluna - {name}')
    plt.ylabel('%'); plt.tight_layout(); plt.show()

    # duplicatas
    dup_mask = df.duplicated(keep=False)
    print('linhas duplicadas:', int(dup_mask.sum()))
    if dup_mask.any():
        display(df[dup_mask].head(10))

    # outliers (IQR) em colunas numéricas
    num_cols = df.select_dtypes(include=np.number).columns.tolist()
    for c in num_cols:
        s = pd.to_numeric(df[c], errors='coerce').dropna()
        if s.empty:
            continue
        q1, q3 = s.quantile([0.25, 0.75])
        iqr = q3 - q1
        low, high = q1 - 1.5*iqr, q3 + 1.5*iqr
        out_count = int(((s < low) | (s > high)).sum())
        print(f'outliers em {c}: {out_count} (limites {low:.3f} ~ {high:.3f})')
# Out:
# === Order ===
#                       %_missing
# extraInfo                 59.05
# scheduledAt               48.40
# id                         0.00
# createdAt                  0.00
# customer                   0.00
# companyId                  0.00
# containerId                0.00
# engineId                   0.00
# displayId                  0.00
# engineType                 0.00
# engineName                 0.00
# integrationId              0.00
# isTest                     0.00
# orderTiming                0.00
# integrated                 0.00
# orderType                  0.00
# salesChannel               0.00
# status                     0.00
# preparationTime            0.00
# takeOutTimeInSeconds       0.00
# linhas duplicadas: 0
# outliers em id: 0 (limites -998.500 ~ 2999.500)
# outliers em customer: 0 (limites -501.000 ~ 1467.000)
# outliers em integrationId: 0 (limites -3681.000 ~ 14529.000)
# outliers em preparationTime: 0 (limites -38.500 ~ 133.500)
# outliers em takeOutTimeInSeconds: 0 (limites -1681.375 ~ 5345.625)
# outliers em totalAmount: 69 (limites -31.656 ~ 141.454)
#
# === Customer ===
#               %_missing
# externalCode       62.6
# enrichedAt         49.6
# enrichedBy         49.6
# gender             25.9
# taxId               0.0
# dateOfBirth         0.0
# name                0.0
# id                  0.0
# isEnriched          0.0
# status              0.0
# createdAt           0.0
# createdBy           0.0
# updatedAt           0.0
# updatedBy           0.0
# phone               0.0
# email               0.0
# linhas duplicadas: 0
# outliers em id: 0 (limites -498.500 ~ 1499.500)
# outliers em status: 0 (limites -0.500 ~ 3.500)
#
# === CampaignQueue ===
#                  %_missing
# response             68.24
# sendAt               34.24
# id                    0.00
# jobId                 0.00
# storeInstanceId       0.00
# customerId            0.00
# campaignId            0.00
# storeId               0.00
# scheduledAt           0.00
#  phoneNumber          0.00
# status                0.00
# message               0.00
# createdAt             0.00
# createdBy             0.00
# updatedAt             0.00
# updatedBy             0.00
# linhas duplicadas: 0
# outliers em id: 0 (limites -2498.500 ~ 7499.500)
# outliers em jobId: 0 (limites -2498.500 ~ 7499.500)
# outliers em campaignId: 0 (limites -991.750 ~ 2998.250)
# outliers em customerId: 0 (limites -500.500 ~ 1487.500)
# outliers em status: 0 (limites -2.500 ~ 9.500)
#
# === Campaign ===
#              %_missing
# description      20.25
# badge            15.95
# segmentId         0.00
# templateId        0.00
# storeId           0.00
# id                0.00
# name              0.00
# type              0.00
# status            0.00
# isDefault         0.00
# createdAt         0.00
# createdBy         0.00
# updatedAt         0.00
# updatedBy         0.00
# linhas duplicadas: 0
# outliers em id: 0 (limites -998.500 ~ 2999.500)
# outliers em segmentId: 0 (limites -1426.375 ~ 2390.625)
# outliers em templateId: 0 (limites -998.500 ~ 2999.500)
# outliers em type: 0 (limites -0.500 ~ 3.500)
# outliers em status: 0 (limites -1.625 ~ 7.375)
